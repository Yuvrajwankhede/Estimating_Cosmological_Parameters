# %%
# !pip install numpy
# !pip install uncertainties
# Out:
# Requirement already satisfied: numpy in c:\users\yuvra\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: uncertainties in c:\users\yuvra\anaconda3\lib\site-packages (3.2.2)

# %% [markdown]
# ### Importing necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from uncertainties import ufloat
import astropy.units as u
from astropy.cosmology import FlatLambdaCDM
from scipy.optimize import curve_fit

# %% [markdown]
# ### Loading the data file containting the redshifts and apparent magnitudes as 'file'

# %%
file = np.loadtxt(fname='SNe_Wankhede.csv',  skiprows=1, delimiter=',')
#print(file.shape[:]) # Hashtagging, since its unnecesary to print but can be used if needed.

# %% [markdown]
# <span style='font-size:large'>**Q1. Produce a plot of apparent magnitude against redshift for all the SNe in their catalogue.**</span><span style='font-size:large'> </span>

# %%
#Setting the redshifts column in 'File' as 'x', apparent magnitudes column as 'y' and errors in apparent magnitudes as 'yerr'

#Let,
x = file[:, 0] #redshifts
y = file[:, 1] #Apparent magnitudes 
yerr = file[:, 2] #error in apparent magnitudes

#SOLUTION:
#PLOTTING THE GRAPH.

plt.scatter(x, y, color='blue', s=1)
plt.xlabel('Redshift', color='green')
plt.ylabel('Apparent Magnitude', color='green')
plt.errorbar(x, y, yerr=yerr, fmt='o', markersize=2, color='r', ecolor='gray', capsize=3)
plt.title('Apparent magnitude against redshift', color='green')
plt.tight_layout() #no overlapping
plt.savefig('Apparent magnitude against redshift.png', dpi=300)
plt.show()

# %% [markdown]
# <span style='font-size:large'>**Q2. Calculate the luminosity distance \(in Mpc\) to the lowest redshift SNe in their catalogue, using only its apparent and absolute magnitudes \(see the appendix for the formula relating apparent and absolute magnitudes to luminosity distance\)**</span>

# %%
#calculating the luminosity distance using apparent magnitude in 'y' column of file 'file'.

print('Lowest redshift is: ', np.min(x))

#creating a filter to find the apparent magnitude corresponding to the lowest redshift
min_redshift_index = np.where(x == np.min(x))
apparent_mag = y[min_redshift_index]
apparent_mag_error = yerr[min_redshift_index]

print('Apparent Magnitude of lowest redshft is: ', apparent_mag, '+/-', apparent_mag_error)

#SOLUTION:

Apparent_mag = ufloat(17.3572, 0.006)
ABSOLUTE_MAGNITUDE = -19.5
#distance_modulus (u) = Absolute magnitude - apparent magnitude

def find_luminosity_distance():
    u = ABSOLUTE_MAGNITUDE - Apparent_mag
    #Applying the formula M = m - 5log10(dL) + 5 to find 'dL=luminosity distance'
    luminosity_distance = 10**(-(u - 5) / 5)
    return luminosity_distance
print('Luminosity distance to the lowest redshift SNe is: ', (find_luminosity_distance())/10**6, 'Mpc')
# Out:
# Lowest redshift is:  0.0554
# Apparent Magnitude of lowest redshft is:  [17.3572] +/- [0.006]
# Luminosity distance to the lowest redshift SNe is:  235.2+/-0.6 Mpc

# %% [markdown]
# <span style='font-size:medium'>**Q3. Use the lowest redshift SNe in their catalogue to obtain an initial estimate of Hubble's Constant, H\_0, which is H\_0\_i from here.** </span>

# %%
#In order to find the H_0 we use the formula; H_0 = c/dL*z
z = np.min(x)
dL = ufloat(235.2, 0.6) #in Mpc
d = dL/(1+z)
c = 3*10**5 #in units of km/s to make calculation easier

#SOLUTION:

def Hubble_constant(z):
    Hubble_constant = c*z/dL
    return Hubble_constant
print("Hubble's contant, H_0_i, using the lowest redshift SNe is: ", Hubble_constant(z), "Km/sec/Mpc")
# Out:
# Hubble's contant, H_0_i, using the lowest redshift SNe is:  70.66+/-0.18 Km/sec/Mpc

# %% [markdown]
# ### 3.1 Initial estimate for the Age of the Universe as per H_0_i

# %%
def H0(z): return c*z/dL   #units are km/s/Mpc
def age_Gyr(z): return (1/H0(z)) * 3.0857e19/3.15576e16 # in Billion years

print("Age of Universe:", age_Gyr(z), "Billion years")
# Out:
# Age of Universe: 13.837+/-0.035 Billion years

# %% [markdown]
# <span style='font-size:medium'>**Q4. Calculate the luminosity distances \(in Mpc\) to every SNe in their catalogue, again, using only their apparent and absloute magnitudes.** </span>

# %%
Apparent_mag = [ufloat(nom_val, std_dev) for nom_val, std_dev in zip(y, yerr)]
ABSOLUTE_MAGNITUDE = -19.5

#SOLUTION:
#defining distance_modulus = u = Absolute magnitude - apparent magnitude

def luminosity_distance():
    u = [ABSOLUTE_MAGNITUDE - a for a in Apparent_mag]
    # Applying the formula M = m - 5log10(dL) + 5 to find 'dL'
    luminosity_distance = [10**(-(val - 5) / 5) for val in u]
    return luminosity_distance

#Using f string formatting in print for convinient display of the output of luminosity distance with redshifts. 
print(f"The luminosity distances in Mpc for redshifts corresponding to each apparent magnitude are as follows:\n")
for i, (redshift, distance) in enumerate(zip(x, luminosity_distance())):
  print(f"Redshift: {redshift:.4f}, Luminosity Distance: {(distance / 10**6):.2f} Mpc")
# Out:
# The luminosity distances in Mpc for redshifts corresponding to each apparent magnitude are as follows:
#
# Redshift: 0.1704, Luminosity Distance: 769.27+/-21.86 Mpc
# Redshift: 0.2897, Luminosity Distance: 1269.70+/-108.87 Mpc
# Redshift: 0.1683, Luminosity Distance: 760.29+/-21.04 Mpc
# Redshift: 0.1991, Luminosity Distance: 915.33+/-36.04 Mpc
# Redshift: 0.2376, Luminosity Distance: 1171.33+/-66.73 Mpc
# Redshift: 0.2330, Luminosity Distance: 1208.48+/-66.12 Mpc
# Redshift: 0.2083, Luminosity Distance: 1003.64+/-43.45 Mpc
# Redshift: 0.2621, Luminosity Distance: 1229.14+/-85.81 Mpc
# Redshift: 0.2391, Luminosity Distance: 1124.60+/-64.89 Mpc
# Redshift: 0.1155, Luminosity Distance: 503.96+/-6.34 Mpc
# Redshift: 0.2777, Luminosity Distance: 1205.20+/-94.80 Mpc
# Redshift: 0.2899, Luminosity Distance: 1373.54+/-117.97 Mpc
# Redshift: 0.2891, Luminosity Distance: 1362.45+/-116.33 Mpc
# Redshift: 0.0992, Luminosity Distance: 427.25+/-3.92 Mpc
# Redshift: 0.2362, Luminosity Distance: 1091.29+/-61.41 Mpc
# Redshift: 0.2324, Luminosity Distance: 1026.64+/-55.84 Mpc
# Redshift: 0.2714, Luminosity Distance: 1366.85+/-102.54 Mpc
# Redshift: 0.2678, Luminosity Distance: 1403.98+/-102.48 Mpc
# Redshift: 0.2197, Luminosity Distance: 998.39+/-48.28 Mpc
# Redshift: 0.1737, Luminosity Distance: 766.06+/-22.65 Mpc
# Redshift: 0.2882, Luminosity Distance: 1198.95+/-101.76 Mpc
# Redshift: 0.2296, Luminosity Distance: 1007.02+/-53.42 Mpc
# Redshift: 0.2770, Luminosity Distance: 1300.29+/-101.74 Mpc
# Redshift: 0.2076, Luminosity Distance: 1001.80+/-43.04 Mpc
# Redshift: 0.2842, Luminosity Distance: 1285.64+/-106.04 Mpc
# Redshift: 0.2775, Luminosity Distance: 1402.75+/-110.14 Mpc
# Redshift: 0.2652, Luminosity Distance: 1114.04+/-79.67 Mpc
# Redshift: 0.2963, Luminosity Distance: 1431.92+/-128.59 Mpc
# Redshift: 0.2201, Luminosity Distance: 975.26+/-47.38 Mpc
# Redshift: 0.2207, Luminosity Distance: 1038.20+/-50.73 Mpc
# Redshift: 0.1365, Luminosity Distance: 601.87+/-10.73 Mpc
# Redshift: 0.2570, Luminosity Distance: 1256.72+/-84.21 Mpc
# Redshift: 0.1937, Luminosity Distance: 875.99+/-32.56 Mpc
# Redshift: 0.1505, Luminosity Distance: 658.84+/-14.41 Mpc
# Redshift: 0.2066, Luminosity Distance: 924.27+/-39.33 Mpc
# Redshift: 0.2171, Luminosity Distance: 1016.76+/-47.95 Mpc
# Redshift: 0.1643, Luminosity Distance: 737.39+/-19.39 Mpc
# Redshift: 0.2646, Luminosity Distance: 1293.12+/-92.07 Mpc
# Redshift: 0.2816, Luminosity Distance: 1179.61+/-95.45 Mpc
# Redshift: 0.2808, Luminosity Distance: 1264.79+/-101.76 Mpc
# Redshift: 0.2767, Luminosity Distance: 1201.93+/-93.88 Mpc
# Redshift: 0.1634, Luminosity Distance: 733.97+/-19.10 Mpc
# Redshift: 0.1351, Luminosity Distance: 575.23+/-10.04 Mpc
# Redshift: 0.2728, Luminosity Distance: 1485.73+/-112.62 Mpc
# Redshift: 0.1327, Luminosity Distance: 580.95+/-9.77 Mpc
# Redshift: 0.2221, Luminosity Distance: 1058.91+/-52.42 Mpc
# Redshift: 0.1725, Luminosity Distance: 812.61+/-23.69 Mpc
# Redshift: 0.2490, Luminosity Distance: 1109.12+/-69.62 Mpc
# Redshift: 0.2582, Luminosity Distance: 1264.45+/-85.60 Mpc
# Redshift: 0.2486, Luminosity Distance: 1239.54+/-77.52 Mpc
# Redshift: 0.2137, Luminosity Distance: 1016.48+/-46.44 Mpc
# Redshift: 0.2601, Luminosity Distance: 1249.22+/-85.83 Mpc
# Redshift: 0.1693, Luminosity Distance: 779.15+/-21.85 Mpc
# Redshift: 0.2674, Luminosity Distance: 1143.40+/-83.20 Mpc
# Redshift: 0.2619, Luminosity Distance: 1214.17+/-84.65 Mpc
# Redshift: 0.2078, Luminosity Distance: 922.87+/-39.74 Mpc
# Redshift: 0.2242, Luminosity Distance: 1034.24+/-52.20 Mpc
# Redshift: 0.1718, Luminosity Distance: 792.61+/-22.92 Mpc
# Redshift: 0.2246, Luminosity Distance: 1051.67+/-53.27 Mpc
# Redshift: 0.1892, Luminosity Distance: 852.83+/-30.16 Mpc
# Redshift: 0.2460, Luminosity Distance: 1294.67+/-79.24 Mpc
# Redshift: 0.1492, Luminosity Distance: 672.48+/-14.46 Mpc
# Redshift: 0.1717, Luminosity Distance: 761.48+/-21.99 Mpc
# Redshift: 0.2074, Luminosity Distance: 978.81+/-41.97 Mpc
# Redshift: 0.1322, Luminosity Distance: 584.33+/-9.74 Mpc
# Redshift: 0.2749, Luminosity Distance: 1293.66+/-99.61 Mpc
# Redshift: 0.2709, Luminosity Distance: 1336.72+/-99.91 Mpc
# Redshift: 0.2338, Luminosity Distance: 1076.51+/-59.29 Mpc
# Redshift: 0.2843, Luminosity Distance: 1386.56+/-114.49 Mpc
# Redshift: 0.1654, Luminosity Distance: 776.43+/-20.70 Mpc
# Redshift: 0.0844, Luminosity Distance: 363.03+/-2.37 Mpc
# Redshift: 0.1664, Luminosity Distance: 773.78+/-20.92 Mpc
# Redshift: 0.2013, Luminosity Distance: 897.35+/-36.16 Mpc
# Redshift: 0.2008, Luminosity Distance: 941.41+/-37.76 Mpc
# Redshift: 0.2245, Luminosity Distance: 1038.15+/-52.54 Mpc
# Redshift: 0.2418, Luminosity Distance: 1055.60+/-62.37 Mpc
# Redshift: 0.1914, Luminosity Distance: 902.65+/-32.71 Mpc
# Redshift: 0.1769, Luminosity Distance: 782.31+/-24.03 Mpc
# Redshift: 0.2118, Luminosity Distance: 1059.99+/-47.50 Mpc
# Redshift: 0.2189, Luminosity Distance: 941.37+/-45.22 Mpc
# Redshift: 0.2940, Luminosity Distance: 1355.81+/-119.82 Mpc
# Redshift: 0.2439, Luminosity Distance: 1107.95+/-66.64 Mpc
# Redshift: 0.2819, Luminosity Distance: 1243.43+/-100.84 Mpc
# Redshift: 0.1682, Luminosity Distance: 799.10+/-22.08 Mpc
# Redshift: 0.2200, Luminosity Distance: 1008.83+/-48.97 Mpc
# Redshift: 0.2245, Luminosity Distance: 1069.25+/-54.12 Mpc
# Redshift: 0.1682, Luminosity Distance: 725.70+/-20.05 Mpc
# Redshift: 0.2060, Luminosity Distance: 926.40+/-39.16 Mpc
# Redshift: 0.2655, Luminosity Distance: 1257.30+/-90.15 Mpc
# Redshift: 0.2270, Luminosity Distance: 1005.87+/-52.07 Mpc
# Redshift: 0.1928, Luminosity Distance: 856.37+/-31.51 Mpc
# Redshift: 0.2142, Luminosity Distance: 858.06+/-39.36 Mpc
# Redshift: 0.2819, Luminosity Distance: 1255.22+/-101.79 Mpc
# Redshift: 0.2893, Luminosity Distance: 1390.79+/-119.00 Mpc
# Redshift: 0.1560, Luminosity Distance: 689.26+/-16.25 Mpc
# Redshift: 0.2429, Luminosity Distance: 1153.40+/-68.79 Mpc
# Redshift: 0.2579, Luminosity Distance: 1121.09+/-75.74 Mpc
# Redshift: 0.1821, Luminosity Distance: 812.87+/-26.54 Mpc
# Redshift: 0.1959, Luminosity Distance: 869.72+/-33.12 Mpc
# Redshift: 0.1412, Luminosity Distance: 628.29+/-12.04 Mpc
# Redshift: 0.1719, Luminosity Distance: 759.24+/-21.96 Mpc
# Redshift: 0.1070, Luminosity Distance: 469.57+/-5.04 Mpc
# Redshift: 0.2537, Luminosity Distance: 1178.26+/-76.89 Mpc
# Redshift: 0.1467, Luminosity Distance: 664.75+/-13.78 Mpc
# Redshift: 0.2586, Luminosity Distance: 1225.91+/-83.27 Mpc
# Redshift: 0.1483, Luminosity Distance: 655.60+/-13.92 Mpc
# Redshift: 0.2685, Luminosity Distance: 1324.52+/-97.23 Mpc
# Redshift: 0.1611, Luminosity Distance: 732.45+/-18.48 Mpc
# Redshift: 0.1907, Luminosity Distance: 838.26+/-30.15 Mpc
# Redshift: 0.2098, Luminosity Distance: 934.54+/-41.06 Mpc
# Redshift: 0.1814, Luminosity Distance: 813.84+/-26.35 Mpc
# Redshift: 0.1983, Luminosity Distance: 859.41+/-33.56 Mpc
# Redshift: 0.2505, Luminosity Distance: 1241.82+/-78.92 Mpc
# Redshift: 0.2689, Luminosity Distance: 1328.80+/-97.79 Mpc
# Redshift: 0.2401, Luminosity Distance: 1172.90+/-68.27 Mpc
# Redshift: 0.2268, Luminosity Distance: 1063.11+/-54.98 Mpc
# Redshift: 0.2639, Luminosity Distance: 1270.69+/-89.94 Mpc
# Redshift: 0.1694, Luminosity Distance: 791.48+/-22.20 Mpc
# Redshift: 0.2947, Luminosity Distance: 1327.27+/-117.85 Mpc
# Redshift: 0.2677, Luminosity Distance: 1321.72+/-96.41 Mpc
# Redshift: 0.2511, Luminosity Distance: 1097.44+/-70.10 Mpc
# Redshift: 0.2178, Luminosity Distance: 956.62+/-45.46 Mpc
# Redshift: 0.2942, Luminosity Distance: 1419.65+/-125.72 Mpc
# Redshift: 0.2888, Luminosity Distance: 1283.45+/-109.40 Mpc
# Redshift: 0.2525, Luminosity Distance: 1164.45+/-75.24 Mpc
# Redshift: 0.2272, Luminosity Distance: 1073.84+/-55.73 Mpc
# Redshift: 0.2041, Luminosity Distance: 920.79+/-38.21 Mpc
# Redshift: 0.2544, Luminosity Distance: 1097.89+/-72.05 Mpc
# Redshift: 0.2249, Luminosity Distance: 987.42+/-50.16 Mpc
# Redshift: 0.2075, Luminosity Distance: 950.65+/-40.80 Mpc
# Redshift: 0.2441, Luminosity Distance: 1081.23+/-65.13 Mpc
# Redshift: 0.2378, Luminosity Distance: 1174.95+/-67.04 Mpc
# Redshift: 0.2589, Luminosity Distance: 1065.71+/-72.54 Mpc
# Redshift: 0.1972, Luminosity Distance: 921.93+/-35.58 Mpc
# Redshift: 0.2741, Luminosity Distance: 1296.46+/-99.29 Mpc
# Redshift: 0.2104, Luminosity Distance: 898.09+/-39.66 Mpc
# Redshift: 0.2539, Luminosity Distance: 1241.42+/-81.18 Mpc
# Redshift: 0.2146, Luminosity Distance: 1042.61+/-48.01 Mpc
# Redshift: 0.1828, Luminosity Distance: 789.77+/-26.00 Mpc
# Redshift: 0.2719, Luminosity Distance: 1240.91+/-93.49 Mpc
# Redshift: 0.1994, Luminosity Distance: 885.20+/-34.98 Mpc
# Redshift: 0.2946, Luminosity Distance: 1051.24+/-93.29 Mpc
# Redshift: 0.2298, Luminosity Distance: 1022.26+/-54.33 Mpc
# Redshift: 0.2762, Luminosity Distance: 1247.84+/-97.06 Mpc
# Redshift: 0.2697, Luminosity Distance: 1307.19+/-96.80 Mpc
# Redshift: 0.2946, Luminosity Distance: 1386.44+/-123.10 Mpc
# Redshift: 0.2689, Luminosity Distance: 1342.95+/-98.83 Mpc
# Redshift: 0.2828, Luminosity Distance: 1247.79+/-101.88 Mpc
# Redshift: 0.2291, Luminosity Distance: 1081.58+/-57.13 Mpc
# Redshift: 0.2379, Luminosity Distance: 1080.74+/-61.71 Mpc
# Redshift: 0.2900, Luminosity Distance: 1338.69+/-115.10 Mpc
# Redshift: 0.2750, Luminosity Distance: 1341.96+/-103.39 Mpc
# Redshift: 0.2706, Luminosity Distance: 1130.84+/-84.31 Mpc
# Redshift: 0.1932, Luminosity Distance: 885.77+/-32.76 Mpc
# Redshift: 0.2678, Luminosity Distance: 1334.01+/-97.37 Mpc
# Redshift: 0.2284, Luminosity Distance: 1144.99+/-60.06 Mpc
# Redshift: 0.1789, Luminosity Distance: 821.94+/-25.85 Mpc
# Redshift: 0.2984, Luminosity Distance: 1553.32+/-141.49 Mpc
# Redshift: 0.1656, Luminosity Distance: 711.38+/-19.03 Mpc
# Redshift: 0.2901, Luminosity Distance: 1537.30+/-132.25 Mpc
# Redshift: 0.2770, Luminosity Distance: 1358.88+/-106.32 Mpc
# Redshift: 0.2815, Luminosity Distance: 1301.13+/-105.22 Mpc
# Redshift: 0.1917, Luminosity Distance: 902.03+/-32.82 Mpc
# Redshift: 0.1546, Luminosity Distance: 705.18+/-16.33 Mpc
# Redshift: 0.2778, Luminosity Distance: 1307.68+/-102.92 Mpc
# Redshift: 0.2676, Luminosity Distance: 1309.00+/-95.37 Mpc
# Redshift: 0.2798, Luminosity Distance: 1259.22+/-100.55 Mpc
# Redshift: 0.1931, Luminosity Distance: 834.03+/-30.80 Mpc
# Redshift: 0.2693, Luminosity Distance: 1234.18+/-91.17 Mpc
# Redshift: 0.2005, Luminosity Distance: 921.17+/-36.82 Mpc
# Redshift: 0.2805, Luminosity Distance: 1317.83+/-105.78 Mpc
# Redshift: 0.2956, Luminosity Distance: 1672.78+/-149.52 Mpc
# Redshift: 0.1618, Luminosity Distance: 712.20+/-18.14 Mpc
# Redshift: 0.2072, Luminosity Distance: 1008.09+/-43.13 Mpc
# Redshift: 0.1432, Luminosity Distance: 619.75+/-12.22 Mpc
# Redshift: 0.1531, Luminosity Distance: 681.62+/-15.44 Mpc
# Redshift: 0.2678, Luminosity Distance: 1231.74+/-89.91 Mpc
# Redshift: 0.2749, Luminosity Distance: 1242.91+/-95.70 Mpc
# Redshift: 0.0707, Luminosity Distance: 300.54+/-1.36 Mpc
# Redshift: 0.2027, Luminosity Distance: 916.85+/-37.49 Mpc
# Redshift: 0.2106, Luminosity Distance: 942.67+/-41.76 Mpc
# Redshift: 0.1763, Luminosity Distance: 804.34+/-24.52 Mpc
# Redshift: 0.1910, Luminosity Distance: 958.74+/-34.57 Mpc
# Redshift: 0.2712, Luminosity Distance: 1470.96+/-110.21 Mpc
# Redshift: 0.1656, Luminosity Distance: 713.25+/-19.08 Mpc
# Redshift: 0.2671, Luminosity Distance: 1206.81+/-87.59 Mpc
# Redshift: 0.1980, Luminosity Distance: 838.11+/-32.61 Mpc
# Redshift: 0.2948, Luminosity Distance: 1597.50+/-141.99 Mpc
# Redshift: 0.2642, Luminosity Distance: 1208.37+/-85.75 Mpc
# Redshift: 0.2921, Luminosity Distance: 1572.53+/-137.23 Mpc
# Redshift: 0.2619, Luminosity Distance: 1250.03+/-87.15 Mpc
# Redshift: 0.2051, Luminosity Distance: 895.32+/-37.52 Mpc
# Redshift: 0.2613, Luminosity Distance: 1384.01+/-96.05 Mpc
# Redshift: 0.2333, Luminosity Distance: 969.53+/-53.13 Mpc
# Redshift: 0.2211, Luminosity Distance: 1065.86+/-52.28 Mpc
# Redshift: 0.0988, Luminosity Distance: 433.33+/-3.93 Mpc
# Redshift: 0.2845, Luminosity Distance: 1323.67+/-109.42 Mpc
# Redshift: 0.2291, Luminosity Distance: 939.38+/-49.62 Mpc
# Redshift: 0.1952, Luminosity Distance: 867.60+/-32.76 Mpc
# Redshift: 0.2333, Luminosity Distance: 1084.08+/-59.41 Mpc
# Redshift: 0.2847, Luminosity Distance: 1358.75+/-112.51 Mpc
# Redshift: 0.1408, Luminosity Distance: 629.91+/-11.98 Mpc
# Redshift: 0.2786, Luminosity Distance: 1312.86+/-103.93 Mpc
# Redshift: 0.2880, Luminosity Distance: 1346.17+/-114.07 Mpc
# Redshift: 0.2280, Luminosity Distance: 1024.61+/-53.56 Mpc
# Redshift: 0.2540, Luminosity Distance: 1273.74+/-83.29 Mpc
# Redshift: 0.2193, Luminosity Distance: 1061.21+/-51.17 Mpc
# Redshift: 0.1644, Luminosity Distance: 725.24+/-19.10 Mpc
# Redshift: 0.2583, Luminosity Distance: 1236.74+/-83.78 Mpc
# Redshift: 0.2649, Luminosity Distance: 1199.33+/-85.55 Mpc
# Redshift: 0.2884, Luminosity Distance: 1066.84+/-90.69 Mpc
# Redshift: 0.2517, Luminosity Distance: 1110.35+/-71.28 Mpc
# Redshift: 0.1806, Luminosity Distance: 834.76+/-26.79 Mpc
# Redshift: 0.2579, Luminosity Distance: 1193.27+/-80.56 Mpc
# Redshift: 0.2884, Luminosity Distance: 1473.94+/-125.30 Mpc
# Redshift: 0.2386, Luminosity Distance: 1115.94+/-64.14 Mpc
# Redshift: 0.2945, Luminosity Distance: 1393.22+/-123.57 Mpc
# Redshift: 0.2333, Luminosity Distance: 1037.10+/-56.83 Mpc
# Redshift: 0.1957, Luminosity Distance: 893.35+/-33.94 Mpc
# Redshift: 0.2887, Luminosity Distance: 1345.24+/-114.61 Mpc
# Redshift: 0.2932, Luminosity Distance: 1418.14+/-124.67 Mpc
# Redshift: 0.2481, Luminosity Distance: 1203.26+/-74.97 Mpc
# Redshift: 0.2635, Luminosity Distance: 1273.03+/-89.87 Mpc
# Redshift: 0.2335, Luminosity Distance: 1051.14+/-57.75 Mpc
# Redshift: 0.2192, Luminosity Distance: 999.72+/-48.11 Mpc
# Redshift: 0.1386, Luminosity Distance: 594.84+/-10.96 Mpc
# Redshift: 0.2582, Luminosity Distance: 1085.03+/-73.40 Mpc
# Redshift: 0.2458, Luminosity Distance: 1173.82+/-71.73 Mpc
# Redshift: 0.2457, Luminosity Distance: 1110.50+/-67.81 Mpc
# Redshift: 0.2631, Luminosity Distance: 1187.08+/-83.59 Mpc
# Redshift: 0.1560, Luminosity Distance: 718.19+/-16.93 Mpc
# Redshift: 0.2341, Luminosity Distance: 1147.68+/-63.42 Mpc
# Redshift: 0.2169, Luminosity Distance: 860.40+/-40.53 Mpc
# Redshift: 0.2446, Luminosity Distance: 1150.91+/-69.59 Mpc
# Redshift: 0.2923, Luminosity Distance: 1292.59+/-112.92 Mpc
# Redshift: 0.2807, Luminosity Distance: 1537.66+/-123.64 Mpc
# Redshift: 0.1567, Luminosity Distance: 692.34+/-16.52 Mpc
# Redshift: 0.2816, Luminosity Distance: 1385.42+/-112.10 Mpc
# Redshift: 0.1361, Luminosity Distance: 609.82+/-10.81 Mpc
# Redshift: 0.1011, Luminosity Distance: 438.71+/-4.18 Mpc
# Redshift: 0.2859, Luminosity Distance: 1485.05+/-123.99 Mpc
# Redshift: 0.2440, Luminosity Distance: 1252.33+/-75.38 Mpc
# Redshift: 0.2818, Luminosity Distance: 1247.50+/-101.11 Mpc
# Redshift: 0.1588, Luminosity Distance: 713.12+/-17.47 Mpc
# Redshift: 0.2588, Luminosity Distance: 1184.24+/-80.55 Mpc
# Redshift: 0.2457, Luminosity Distance: 1162.52+/-70.99 Mpc
# Redshift: 0.2719, Luminosity Distance: 1365.65+/-102.83 Mpc
# Redshift: 0.2335, Luminosity Distance: 1085.28+/-59.57 Mpc
# Redshift: 0.2725, Luminosity Distance: 1374.11+/-103.97 Mpc
# Redshift: 0.2691, Luminosity Distance: 1305.87+/-96.28 Mpc
# Redshift: 0.2030, Luminosity Distance: 914.96+/-37.50 Mpc
# Redshift: 0.2125, Luminosity Distance: 943.97+/-42.60 Mpc
# Redshift: 0.2783, Luminosity Distance: 1157.71+/-91.43 Mpc
# Redshift: 0.2376, Luminosity Distance: 1044.96+/-59.48 Mpc
# Redshift: 0.2697, Luminosity Distance: 1242.34+/-92.00 Mpc
# Redshift: 0.1546, Luminosity Distance: 681.96+/-15.80 Mpc
# Redshift: 0.2591, Luminosity Distance: 1225.07+/-83.50 Mpc
# Redshift: 0.1832, Luminosity Distance: 805.60+/-26.64 Mpc
# Redshift: 0.2597, Luminosity Distance: 1303.83+/-89.34 Mpc
# Redshift: 0.2446, Luminosity Distance: 1226.37+/-74.21 Mpc
# Redshift: 0.2039, Luminosity Distance: 925.29+/-38.27 Mpc
# Redshift: 0.2917, Luminosity Distance: 1588.99+/-138.23 Mpc
# Redshift: 0.2488, Luminosity Distance: 1209.15+/-75.79 Mpc
# Redshift: 0.1704, Luminosity Distance: 724.64+/-20.59 Mpc
# Redshift: 0.2189, Luminosity Distance: 980.08+/-47.03 Mpc
# Redshift: 0.1709, Luminosity Distance: 756.28+/-21.63 Mpc
# Redshift: 0.2511, Luminosity Distance: 1258.93+/-80.41 Mpc
# Redshift: 0.2953, Luminosity Distance: 1446.04+/-128.99 Mpc
# Redshift: 0.2932, Luminosity Distance: 1240.22+/-109.03 Mpc
# Redshift: 0.1437, Luminosity Distance: 618.90+/-12.28 Mpc
# Redshift: 0.1799, Luminosity Distance: 805.42+/-25.63 Mpc
# Redshift: 0.2361, Luminosity Distance: 1042.75+/-58.63 Mpc
# Redshift: 0.2326, Luminosity Distance: 1054.82+/-57.47 Mpc
# Redshift: 0.2947, Luminosity Distance: 1414.16+/-125.63 Mpc
# Redshift: 0.1239, Luminosity Distance: 530.25+/-7.72 Mpc
# Redshift: 0.2097, Luminosity Distance: 1023.25+/-44.91 Mpc
# Redshift: 0.1108, Luminosity Distance: 488.00+/-5.62 Mpc
# Redshift: 0.2534, Luminosity Distance: 1220.84+/-79.44 Mpc
# Redshift: 0.2174, Luminosity Distance: 1050.70+/-49.74 Mpc
# Redshift: 0.2325, Luminosity Distance: 1094.36+/-59.57 Mpc
# Redshift: 0.1800, Luminosity Distance: 817.03+/-26.04 Mpc
# Redshift: 0.2285, Luminosity Distance: 1148.10+/-60.27 Mpc
# Redshift: 0.2946, Luminosity Distance: 1646.34+/-146.17 Mpc
# Redshift: 0.0554, Luminosity Distance: 235.20+/-0.65 Mpc
# Redshift: 0.2822, Luminosity Distance: 1396.24+/-113.49 Mpc
# Redshift: 0.2113, Luminosity Distance: 1030.05+/-45.92 Mpc
# Redshift: 0.2362, Luminosity Distance: 1028.16+/-57.86 Mpc
# Redshift: 0.2111, Luminosity Distance: 909.03+/-40.44 Mpc
# Redshift: 0.2806, Luminosity Distance: 1502.45+/-120.74 Mpc
# Redshift: 0.1887, Luminosity Distance: 817.26+/-28.75 Mpc
# Redshift: 0.2825, Luminosity Distance: 1358.63+/-110.68 Mpc
# Redshift: 0.1873, Luminosity Distance: 852.71+/-29.53 Mpc
# Redshift: 0.1861, Luminosity Distance: 873.17+/-29.84 Mpc
# Redshift: 0.2463, Luminosity Distance: 1092.40+/-67.06 Mpc
# Redshift: 0.2669, Luminosity Distance: 1381.27+/-100.12 Mpc
# Redshift: 0.1610, Luminosity Distance: 747.45+/-18.83 Mpc
# Redshift: 0.2751, Luminosity Distance: 1224.11+/-94.42 Mpc
# Redshift: 0.2700, Luminosity Distance: 1310.51+/-97.29 Mpc
# Redshift: 0.2774, Luminosity Distance: 1518.94+/-119.19 Mpc
# Redshift: 0.2036, Luminosity Distance: 905.48+/-37.36 Mpc

# %% [markdown]
# <span style='font-size:medium'>**Q5. Calculate the luminosity distance to redshift z = zmax, where zmax is the redshift of the highest redshift SN in the catalogue, assuming a cosmological model where ΩM,0 = 0.5, ΩD,0 = 0.5 and H\_0 = H\_0\_i**</span>

# %%
#As we have from above, 
H_0_i = ufloat(70.66, 0.18)

#Using astropy.cosmology, we set up Omega_m_0 as 0.5, and H_0 as H_0_i and Omga_d = 1 - Omega_m
cosmo = FlatLambdaCDM(H0=H_0_i.nominal_value, Om0=0.5) 

#Using the maximum redshift
z_max = np.max(x)
print('Maximum redshift is: ', z_max)

#SOLUTION:
luminosity_distance = cosmo.luminosity_distance(z_max)

# Print the luminosity distance
print("Luminosity distance for max redshift:", luminosity_distance)
# Out:
def apparent_magnitude(redshifts):
    luminosity_distance = cosmo.luminosity_distance(redshifts)
    apparent_magnitude = 5*np.log10(luminosity_distance.to(u.pc).value) - 24.5
    return apparent_magnitude

#setting parameters to plot the graph of the apparent magnitude in Q7 as a superimposed line on the graph in Q1.
redshifts = np.arange(0.01, z_max+0.001, 0.001)
x2 = redshifts
y2 = apparent_magnitude(redshifts)

#THE PLOT

#plot for the graph in Q1.
plt.scatter(x, y, color='r', s=5)

#plot the line of apparent magnitudes as per Q7. 
plt.plot(x2, y2, color='blue', label='Apparent Magnitude per Q7')
plt.xlabel('Redshift', color='green')
plt.ylabel('Apparent Magnitude', color='green')
plt.errorbar(x, y, yerr=yerr, fmt='o', markersize=1, color='r', ecolor='gray', capsize=3)
plt.title('Apparent magnitude against redshift', color='green')
plt.legend()
plt.savefig('Comparative plot of Apparent magnitude against redshift.png', dpi=300)
plt.show()

# %% [markdown]
# <span style='font-size:medium'>**Q9. Obtain best estimates, including uncertainties, for ΩM,0, ΩD,0 and H0 by fitting their apparent magnitude and redshift data \(Note: the best\-fitting H0 value is likely to similar to, but not the same as, H\_0\_i**</span>

# %%
#Setting up the Constants and initial parameter estimates
initial_H0 = 70.06 #as found above
initial_M = -19.5 #Absolute magnitude given
initial_Om = 0.3 #matter density

#SOLUTION:

#Defining the required functions,
def luminosity_distance(redshift, H0, Om):
    cosmo = FlatLambdaCDM(H0, Om0=Om)
    return cosmo.luminosity_distance(redshift)

def apparent_magnitude(redshift, H0, Om):
    dL = luminosity_distance(redshift, H0, Om)
    d = 10 * u.pc 
    return initial_M + 5 * np.log10(dL/d)

#Setting the initial guess for the parameters,
initial_guess = [initial_H0, initial_Om]

#Curve fitting,
optimized_params, param_covariance = curve_fit(apparent_magnitude, x, y, p0=initial_guess, sigma=yerr, bounds=([65, 0], [75, 1]))

#Extracting optimized parameters and their errors
H0_opt, Om_opt = optimized_params
H0_error, Om_error = np.sqrt(np.diag(param_covariance))

# Printing results
print("Optimized Hubble Constant = {:.3f} +/- {:.3f}".format(H0_opt, H0_error), 'Km/s/Mpc')
print("Optimized Omega matter = {:.3f} +/- {:.3f}".format(Om_opt, Om_error))
print("Optimized Omega dark energy = {:.3f} +/- {:.3f}".format(1 - Om_opt, Om_error))
# Out:
# Optimized Hubble Constant = 73.165 +/- 0.243 Km/s/Mpc
# Optimized Omega matter = 0.502 +/- 0.036
# Optimized Omega dark energy = 0.498 +/- 0.036

# %% [markdown]
# ### 9.1 Final estimate for the Age of the Universe

# %%
#def H0(z): return c*z/dL   #units are km/s/Mpc
def age_Gyr(z): return (1/(H0_opt)) * 3.0857e19/3.15576e16 # in Billion years

print("Age of Universe:", age_Gyr(z), "Billion years")
# Out:
# Age of Universe: 13.364341965122009 Billion years

# %% [markdown]
# <span style='font-size:medium'>**Q10. Repeat Steps 7 and 8 using the best\-fit cosmological parameters \(again, please reproduce the plot from Step 1\).**</span>

# %%
#10.1) Solving for the first part of the question: Calculate the apparent magnitude that a Type 1a would have at a range of redshifts between z = 0 and z = zmax, in increments of 10−3, assuming a cosmological model with the best fit parameters.

#  44.70183189 44.71410333 44.72631498 44.73846742 44.75056126 44.76259707
#  44.77457543 44.78649691 44.79836207 44.81017145 44.82192561 44.83362506
#  44.84527035 44.85686199 44.86840048 44.87988634 44.89132006 44.90270213
#  44.91403303 44.92531323 44.93654321 44.94772343 44.95885434 44.9699364
#  44.98097004 44.9919557  45.00289382 45.01378481 45.02462911 45.03542712
#  45.04617924 45.0568859  45.06754747 45.07816435 45.08873694 45.09926561
#  45.10975073 45.12019269 45.13059184 45.14094855 45.15126318 45.16153608
#  45.1717676  45.18195808 45.19210786 45.20221729 45.21228668 45.22231637
#  45.23230667 45.24225792 45.25217042 45.26204448 45.27188042 45.28167854
#  45.29143913 45.30116249 45.31084892 45.3204987  45.33011212 45.33968947
#  45.34923102 45.35873705 45.36820783 45.37764362 45.38704471 45.39641135
#  45.40574379 45.4150423  45.42430714 45.43353854 45.44273677 45.45190206
#  45.46103467 45.47013482 45.47920276 45.48823872 45.49724294 45.50621564
#  45.51515705 45.5240674  45.5329469  45.54179578 45.55061426 45.55940255
#  45.56816085 45.57688939 45.58558838 45.594258   45.60289848 45.61151001
#  45.62009279 45.62864702 45.6371729  45.64567061 45.65414035 45.66258231
#  45.67099667 45.67938362 45.68774335 45.69607603 45.70438185 45.71266098
#  45.7209136  45.72913988 45.73733999 45.74551412 45.75366242 45.76178506]
# C:\Users\yuvra\AppData\Local\Temp\ipykernel_20700\857562674.py:15: RuntimeWarning: invalid value encountered in log10
#   apparent_magnitude = 5*np.log10(luminosity_distance.to(u.pc).value - 24.5)

# %%
#10.2) Solving for the second part of the Question. Showing the apparent magnitudes calculated above as a line on the plot produced in Step 1. 

#As we have the redshift range, 
redshift = np.arange(0, np.max(x) + 0.001, 0.001) #Using zero as per the Q7 gives the line 'invalid value encountered in log10' in output but using it anyways because asked in the question.

#And,
#As found above, 
H0_opt, Om_opt = optimized_params

#SOLUTION:

#Using cosmology,
cosmo = FlatLambdaCDM(H0=H0_opt, Om0=Om_opt)

#defining the apparent magnitude as above

def apparent_magnitude(redshift):
    luminosity_distance = cosmo.luminosity_distance(redshift)
    apparent_magnitude = 5*np.log10(luminosity_distance.to(u.pc).value)
    return apparent_magnitude
#print(apparent_magnitude(redshift))
x3 = redshift
y3 = apparent_magnitude(x3)

#Plotting the graph

plt.scatter(x, y, color='r', s=5, label='Apparent Mag from SNe catalogue')
plt.plot(x3, y3, color='blue', label='Apparent Mag calculated above in Q10.1')
plt.xlabel('Redshift', color='green')
plt.ylabel('Apparent Magnitude', color='green')
plt.errorbar(x, y, yerr=yerr, fmt='o', markersize=1, color='r', ecolor='gray', capsize=3)
plt.title('Apparent magnitude from SNe Catalogue vs best fit', color='green')
plt.legend()
plt.savefig('Final plot - Best fit with SNe Catalogue.png', dpi=300)
plt.show()
#(The line in the output stating "...invalid value encountered in log10..." is because of the fist value of redshift taken as zero as per the question.)
# Out:
# C:\Users\yuvra\AppData\Local\Temp\ipykernel_20700\3654257143.py:19: RuntimeWarning: divide by zero encountered in log10
#   apparent_magnitude = 5*np.log10(luminosity_distance.to(u.pc).value)
